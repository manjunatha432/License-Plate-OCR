# %%
from ultralytics import YOLO
import cv2
import numpy as np
from datetime import datetime
from heapq import heappush, heappushpop
from collections import Counter
from typing import List, Tuple, Optional
import sys
sys.path.append('../')

# %%
from src.OCR_model import ocr_model

# %%
global plate_results

# %%
# Load the YOLO model
MODEL_PATH = r'../models/PlateYOLO.pt'
model = YOLO(MODEL_PATH)

# %%
class PlateDetector:
    def __init__(self, conf_threshold: float = 0.85, cooldown_frames: int = 1, top_k: int = 5):
        """
        Initialize the PlateDetector.
        Args:
            conf_threshold: Minimum confidence score to consider a detection
            cooldown_frames: Number of frames to wait between captures
            top_k: Number of best frames to maintain
        """
        self.conf_threshold = conf_threshold
        self.cooldown_frames = cooldown_frames
        self.current_cooldown = 60
        self.top_k = top_k
        self.top_detections = []  # Store (confidence, processed_plate)
    
    def _process_plate_region(self, plate_region: np.ndarray) -> Optional[np.ndarray]:
        """Process the plate region with preprocessing steps."""
        if plate_region.size == 0:
            return None
            
        plate_gray = cv2.cvtColor(plate_region, cv2.COLOR_BGR2GRAY)
        _, plate_thresh = cv2.threshold(plate_gray, 0, 255, 
                                      cv2.THRESH_BINARY + cv2.THRESH_OTSU)
        return plate_thresh
    
    def process_frame(self, frame: np.ndarray) -> np.ndarray:
        """Process a single frame and update top detections."""
        plate_results = model(frame)
        processed_frame = frame.copy()
        
        # Decrease cooldown counter
        if self.current_cooldown > 0:
            self.current_cooldown -= 1
        
        for result in plate_results:
            boxes = result.boxes
            for box in boxes:
                if box.cls == 0:  # License plate class
                    conf = float(box.conf[0])
                    x1, y1, x2, y2 = box.xyxy[0].cpu().numpy().astype(int)
                    
                    # Draw rectangle
                    color = (0, 255, 0) if conf >= self.conf_threshold else (0, 165, 255)
                    cv2.rectangle(processed_frame, (x1, y1), (x2, y2), color, 2)
                    cv2.putText(processed_frame, f'Conf: {conf:.2f}', (x1, y1-10), 
                              cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)
                    
                    # If confidence meets threshold and not in cooldown
                    if conf >= self.conf_threshold and self.current_cooldown == 0:
                        plate_region = frame[y1:y2, x1:x2]
                        processed_plate = self._process_plate_region(plate_region)
                        
                        if processed_plate is not None:
                            # Use negative confidence for max heap
                            if len(self.top_detections) < self.top_k:
                                heappush(self.top_detections, (-conf, processed_plate))
                            else:
                                heappushpop(self.top_detections, (-conf, processed_plate))
                            
                            self.current_cooldown = self.cooldown_frames
        
        # Add info to frame
        cv2.putText(processed_frame, f'Threshold: {self.conf_threshold}', 
                    (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2)
        cv2.putText(processed_frame, f'Top Detections: {len(self.top_detections)}/{self.top_k}', 
                    (10, 60), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2)
        
        return processed_frame
    
    def get_top_plates(self) -> List[Tuple[float, np.ndarray]]:
        """Return the top k plates with their confidence scores."""
        return [(-(conf), plate) for conf, plate in sorted(self.top_detections)]
    
    def clear_detections(self):
        """Clear stored detections from memory."""
        self.top_detections = []

def process_video(video_path: str):
    """Process video and return the most common OCR result from top plates."""
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        print(f"Error: Could not open video: {video_path}")
        return None
    
    detector = PlateDetector(conf_threshold=0.85)
    print(f"Starting processing... Press 'q' to stop")
    
    try:
        while True:
            ret, frame = cap.read()
            if not ret:
                break
            
            processed_frame = detector.process_frame(frame)
            cv2.imshow('License Plate Detection', processed_frame)
            
            if cv2.waitKey(1) & 0xFF == ord('q'):
                break
    
    finally:
        cap.release()
        cv2.destroyAllWindows()
    
    # Get top 5 plates and send to OCR
    top_plates = detector.get_top_plates()
    if top_plates:
        # Import OCR model here to avoid circular imports
        
        # Process each plate through OCR
        ocr_results = []
        for conf, plate in top_plates:
            try:
                result = ocr_model(plate,plate_results)
                if result:  # Assuming OCR returns None/empty for failed reads
                    ocr_results.append(result)
                print(f"Plate with confidence {conf:.2f} -> OCR result: {result}")
            except Exception as e:
                print(f"OCR Error: {e}")
        
        # Get the most common OCR result
        if ocr_results:
            final_result = Counter(ocr_results).most_common(1)[0][0]
            print(f"\nFinal plate number: {final_result}")
            
            # Clear detections from memory
            detector.clear_detections()
            return final_result
    
    detector.clear_detections()
    return None

if __name__ == "__main__":
    video_path = '../data/car2.mp4'
    result = process_video(video_path)
# Out:
# Starting processing... Press 'q' to stop
#
# 0: 480x640 1 0, 222.0ms
# Speed: 3.4ms preprocess, 222.0ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 220.5ms
# Speed: 5.6ms preprocess, 220.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 198.4ms
# Speed: 3.1ms preprocess, 198.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 218.4ms
# Speed: 3.3ms preprocess, 218.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 218.2ms
# Speed: 3.1ms preprocess, 218.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 201.9ms
# Speed: 3.7ms preprocess, 201.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 188.7ms
# Speed: 3.2ms preprocess, 188.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 194.3ms
# Speed: 3.3ms preprocess, 194.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 187.9ms
# Speed: 2.8ms preprocess, 187.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 218.7ms
# Speed: 9.8ms preprocess, 218.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 184.8ms
# Speed: 4.2ms preprocess, 184.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 346.4ms
# Speed: 2.7ms preprocess, 346.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 254.4ms
# Speed: 3.5ms preprocess, 254.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 208.5ms
# Speed: 3.9ms preprocess, 208.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 238.7ms
# Speed: 47.5ms preprocess, 238.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 190.6ms
# Speed: 3.7ms preprocess, 190.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 219.9ms
# Speed: 3.7ms preprocess, 219.9ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 199.2ms
# Speed: 3.5ms preprocess, 199.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 211.8ms
# Speed: 2.7ms preprocess, 211.8ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 234.7ms
# Speed: 3.2ms preprocess, 234.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 227.0ms
# Speed: 3.3ms preprocess, 227.0ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 232.0ms
# Speed: 4.1ms preprocess, 232.0ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 221.9ms
# Speed: 3.7ms preprocess, 221.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 184.2ms
# Speed: 3.5ms preprocess, 184.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 197.7ms
# Speed: 3.0ms preprocess, 197.7ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 215.6ms
# Speed: 3.3ms preprocess, 215.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 209.9ms
# Speed: 2.9ms preprocess, 209.9ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 191.3ms
# Speed: 3.4ms preprocess, 191.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 188.1ms
# Speed: 2.6ms preprocess, 188.1ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 181.5ms
# Speed: 2.9ms preprocess, 181.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 173.6ms
# Speed: 3.1ms preprocess, 173.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 186.5ms
# Speed: 2.8ms preprocess, 186.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 184.7ms
# Speed: 3.4ms preprocess, 184.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 172.2ms
# Speed: 2.7ms preprocess, 172.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 175.9ms
# Speed: 3.9ms preprocess, 175.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 193.6ms
# Speed: 3.2ms preprocess, 193.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 180.5ms
# Speed: 3.1ms preprocess, 180.5ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 174.4ms
# Speed: 3.5ms preprocess, 174.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 177.3ms
# Speed: 2.9ms preprocess, 177.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 191.7ms
# Speed: 2.7ms preprocess, 191.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 195.0ms
# Speed: 4.3ms preprocess, 195.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 182.2ms
# Speed: 2.9ms preprocess, 182.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 174.6ms
# Speed: 3.5ms preprocess, 174.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 177.5ms
# Speed: 4.3ms preprocess, 177.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 192.4ms
# Speed: 3.4ms preprocess, 192.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 174.6ms
# Speed: 2.9ms preprocess, 174.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 175.2ms
# Speed: 3.7ms preprocess, 175.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 179.1ms
# Speed: 3.1ms preprocess, 179.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 181.4ms
# Speed: 3.3ms preprocess, 181.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 201.1ms
# Speed: 3.0ms preprocess, 201.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 189.5ms
# Speed: 2.9ms preprocess, 189.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 222.3ms
# Speed: 3.7ms preprocess, 222.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 0s, 180.6ms
# Speed: 3.3ms preprocess, 180.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 0s, 182.5ms
# Speed: 2.9ms preprocess, 182.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 181.0ms
# Speed: 3.0ms preprocess, 181.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 175.4ms
# Speed: 3.2ms preprocess, 175.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 192.1ms
# Speed: 3.3ms preprocess, 192.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 183.2ms
# Speed: 3.0ms preprocess, 183.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 181.6ms
# Speed: 2.9ms preprocess, 181.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 181.2ms
# Speed: 4.3ms preprocess, 181.2ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 178.3ms
# Speed: 3.2ms preprocess, 178.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 0s, 182.0ms
# Speed: 3.0ms preprocess, 182.0ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 0s, 177.1ms
# Speed: 3.6ms preprocess, 177.1ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 0s, 188.0ms
# Speed: 3.3ms preprocess, 188.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 0s, 185.5ms
# Speed: 4.6ms preprocess, 185.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 0s, 186.5ms
# Speed: 3.1ms preprocess, 186.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 0s, 211.9ms
# Speed: 3.1ms preprocess, 211.9ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 179.6ms
# Speed: 3.4ms preprocess, 179.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 186.8ms
# Speed: 3.5ms preprocess, 186.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 174.7ms
# Speed: 3.0ms preprocess, 174.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 183.1ms
# Speed: 3.3ms preprocess, 183.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 197.4ms
# Speed: 3.6ms preprocess, 197.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 179.3ms
# Speed: 3.3ms preprocess, 179.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 183.3ms
# Speed: 3.3ms preprocess, 183.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 208.7ms
# Speed: 2.9ms preprocess, 208.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 424.8ms
# Speed: 3.9ms preprocess, 424.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 183.2ms
# Speed: 3.2ms preprocess, 183.2ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 185.2ms
# Speed: 3.2ms preprocess, 185.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 185.8ms
# Speed: 4.0ms preprocess, 185.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 184.6ms
# Speed: 3.2ms preprocess, 184.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 178.6ms
# Speed: 3.1ms preprocess, 178.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 180.9ms
# Speed: 3.5ms preprocess, 180.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 182.2ms
# Speed: 2.8ms preprocess, 182.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 179.9ms
# Speed: 3.4ms preprocess, 179.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 238.1ms
# Speed: 3.2ms preprocess, 238.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 235.0ms
# Speed: 3.7ms preprocess, 235.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 238.4ms
# Speed: 4.4ms preprocess, 238.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 226.2ms
# Speed: 3.6ms preprocess, 226.2ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 184.8ms
# Speed: 3.1ms preprocess, 184.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 182.4ms
# Speed: 3.0ms preprocess, 182.4ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 182.7ms
# Speed: 3.1ms preprocess, 182.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 184.8ms
# Speed: 3.2ms preprocess, 184.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 180.5ms
# Speed: 2.8ms preprocess, 180.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 179.9ms
# Speed: 3.7ms preprocess, 179.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 182.5ms
# Speed: 3.2ms preprocess, 182.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 184.2ms
# Speed: 3.0ms preprocess, 184.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 184.0ms
# Speed: 3.9ms preprocess, 184.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 184.3ms
# Speed: 2.9ms preprocess, 184.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 184.1ms
# Speed: 3.2ms preprocess, 184.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 184.4ms
# Speed: 3.2ms preprocess, 184.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 186.8ms
# Speed: 3.4ms preprocess, 186.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 188.2ms
# Speed: 3.3ms preprocess, 188.2ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 186.7ms
# Speed: 3.5ms preprocess, 186.7ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 203.2ms
# Speed: 3.6ms preprocess, 203.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 185.6ms
# Speed: 2.9ms preprocess, 185.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 184.0ms
# Speed: 2.9ms preprocess, 184.0ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 184.2ms
# Speed: 3.1ms preprocess, 184.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 185.4ms
# Speed: 3.3ms preprocess, 185.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 184.0ms
# Speed: 3.6ms preprocess, 184.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 181.5ms
# Speed: 4.4ms preprocess, 181.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 187.0ms
# Speed: 2.8ms preprocess, 187.0ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 185.3ms
# Speed: 3.7ms preprocess, 185.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 185.7ms
# Speed: 2.8ms preprocess, 185.7ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 350.4ms
# Speed: 8.6ms preprocess, 350.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 224.4ms
# Speed: 3.3ms preprocess, 224.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 185.3ms
# Speed: 3.7ms preprocess, 185.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 182.8ms
# Speed: 3.5ms preprocess, 182.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 186.9ms
# Speed: 3.3ms preprocess, 186.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 184.0ms
# Speed: 3.3ms preprocess, 184.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 187.0ms
# Speed: 3.1ms preprocess, 187.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 185.9ms
# Speed: 3.1ms preprocess, 185.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 188.8ms
# Speed: 3.1ms preprocess, 188.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 184.6ms
# Speed: 3.0ms preprocess, 184.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 185.2ms
# Speed: 3.6ms preprocess, 185.2ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 187.6ms
# Speed: 3.3ms preprocess, 187.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 183.2ms
# Speed: 3.3ms preprocess, 183.2ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 183.8ms
# Speed: 4.3ms preprocess, 183.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 182.7ms
# Speed: 3.7ms preprocess, 182.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 182.9ms
# Speed: 3.1ms preprocess, 182.9ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 196.5ms
# Speed: 3.1ms preprocess, 196.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 186.9ms
# Speed: 2.8ms preprocess, 186.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 184.8ms
# Speed: 3.3ms preprocess, 184.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 181.0ms
# Speed: 3.8ms preprocess, 181.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 183.8ms
# Speed: 3.0ms preprocess, 183.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 187.1ms
# Speed: 3.8ms preprocess, 187.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 184.8ms
# Speed: 3.2ms preprocess, 184.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 186.2ms
# Speed: 3.3ms preprocess, 186.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 185.3ms
# Speed: 3.9ms preprocess, 185.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 184.6ms
# Speed: 2.9ms preprocess, 184.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 186.1ms
# Speed: 3.7ms preprocess, 186.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 192.6ms
# Speed: 3.8ms preprocess, 192.6ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 191.8ms
# Speed: 3.4ms preprocess, 191.8ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 189.2ms
# Speed: 3.2ms preprocess, 189.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 186.2ms
# Speed: 3.1ms preprocess, 186.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 185.0ms
# Speed: 3.9ms preprocess, 185.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 187.1ms
# Speed: 3.1ms preprocess, 187.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 186.9ms
# Speed: 3.1ms preprocess, 186.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 185.7ms
# Speed: 2.9ms preprocess, 185.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 187.9ms
# Speed: 2.9ms preprocess, 187.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 185.4ms
# Speed: 3.2ms preprocess, 185.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 183.7ms
# Speed: 2.9ms preprocess, 183.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 186.8ms
# Speed: 3.4ms preprocess, 186.8ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 184.5ms
# Speed: 4.7ms preprocess, 184.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 185.6ms
# Speed: 3.6ms preprocess, 185.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 184.8ms
# Speed: 3.3ms preprocess, 184.8ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 183.3ms
# Speed: 4.1ms preprocess, 183.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 186.3ms
# Speed: 3.3ms preprocess, 186.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 186.2ms
# Speed: 3.5ms preprocess, 186.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 186.2ms
# Speed: 3.0ms preprocess, 186.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 185.2ms
# Speed: 3.0ms preprocess, 185.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 187.8ms
# Speed: 3.1ms preprocess, 187.8ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 186.3ms
# Speed: 3.5ms preprocess, 186.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 183.9ms
# Speed: 3.4ms preprocess, 183.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 188.4ms
# Speed: 3.6ms preprocess, 188.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 189.0ms
# Speed: 3.7ms preprocess, 189.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 185.7ms
# Speed: 3.5ms preprocess, 185.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 186.6ms
# Speed: 3.0ms preprocess, 186.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 183.1ms
# Speed: 3.0ms preprocess, 183.1ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 187.8ms
# Speed: 2.8ms preprocess, 187.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 204.1ms
# Speed: 3.5ms preprocess, 204.1ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 188.3ms
# Speed: 2.8ms preprocess, 188.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 184.2ms
# Speed: 3.1ms preprocess, 184.2ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 186.5ms
# Speed: 3.0ms preprocess, 186.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 185.0ms
# Speed: 3.9ms preprocess, 185.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 188.1ms
# Speed: 3.0ms preprocess, 188.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 187.9ms
# Speed: 2.8ms preprocess, 187.9ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 184.1ms
# Speed: 4.2ms preprocess, 184.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 186.7ms
# Speed: 3.0ms preprocess, 186.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 186.2ms
# Speed: 3.7ms preprocess, 186.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 261.8ms
# Speed: 3.0ms preprocess, 261.8ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 254.4ms
# Speed: 11.7ms preprocess, 254.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 199.5ms
# Speed: 2.9ms preprocess, 199.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 195.5ms
# Speed: 3.6ms preprocess, 195.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 204.0ms
# Speed: 3.4ms preprocess, 204.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 190.2ms
# Speed: 4.2ms preprocess, 190.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 201.4ms
# Speed: 3.2ms preprocess, 201.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 188.3ms
# Speed: 3.4ms preprocess, 188.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 227.1ms
# Speed: 3.0ms preprocess, 227.1ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 0, 206.1ms
# Speed: 3.5ms preprocess, 206.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# OCR Error: name 'plate_results' is not defined
# OCR Error: name 'plate_results' is not defined
# OCR Error: name 'plate_results' is not defined
# OCR Error: name 'plate_results' is not defined
# OCR Error: name 'plate_results' is not defined
